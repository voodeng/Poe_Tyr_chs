# %%
import os
import sys
import xml.etree.ElementTree as ET

import numpy as np
import openpyxl
import pandas as pd
import xlrd

from config import *


# 使用自定的名词表打补丁
# 分词，用 ' - '  两边带有空格
# merged_result = os.path.join(HOME_DIR, OUTPUT_DIR, u"trans_use.xlsx")
patch_result = patch_filename

xmdf = pd.read_excel(merge_result_output_filename).fillna('')
tmdf = xmdf.copy()

def _map(data):
    print('===strat replace')
    for index, row in data.iterrows():   # 获取每行的index、row
        if row['Rep'] == '' or row['Rep'] is None or row['Chs'] == '' or row['Chs'] is None:
            continue
        else:
            tuidao(row)
    print('===patch end')
    return data

def _fix(data):
    print('===strat fix')
    for index, row in data.iterrows():   # 获取每行的index、row
        if row['Chs'] == '' or row['Chs'] is None:
            continue
        else:
            im = tmdf[(tmdf['Name']==row['Name']) & (tmdf['ID']==row['ID'])].index
            tmdf.ix[im,'Custom'] = row['Chs']
#             tmdf.ix[ tmdf[tmdf['Name']==row['Name']].iloc[row['ID']]['Refer'],'Custom' ] = row['Chs']
    print('===patch end')
    return data

def tuidao(pre):
    chs = pre['Chs']
    eng = pre['Eng']
    rep = pre['Rep'].split(',')
    r_count = 0
    if chs == '' or chs is None:
        return
    items = tmdf[tmdf['DefaultText'].str.contains(eng, case=False)]

    for i,row in items.iterrows():
        if len(rep) < 2:
            row['Custom'] = row['Custom'].replace(rep[0],chs)
        else:
            for k in rep:
                row['Custom'] = row['Custom'].replace(k,chs)
        r_count +=1
        tmdf.ix[i,'Custom'] = row['Custom']
    print('{co} replaced: {e} {s} ==> {b}'.format(co = r_count, e=eng, s = rep, b = chs))


def patch():

    # 检测英文相等部分 > 检测翻译部分类同部分 > 替换为指定表格的文字
    # mr[mr['DefaultText'].str.contains('Engwithan')]
    # 需要遍历 DataFrame 所有行

    book = openpyxl.load_workbook(patch_filename)
    tr_list = {}
    for sheet in book:
        print('read patch list:' + sheet.title)
        _sn = sheet.title
        pr = pd.read_excel(patch_filename,sheetname=_sn).fillna('')
        tr_list[_sn]=pr

    for x in tr_list:
        if x == 'fix':
            _fix(tr_list[x])
        else:
            _map(tr_list[x])

    tmdf.to_excel(merge_patched,index=False)
    print(merge_patched)
    print('===== file patched and out')

# %%
patch()
# Out:
# 名词
# 地名
# 物品
# 神祇
# 人名
# 状态
# 机制
# 特有
# 武器
# 怪物
# fix
# ===strat replace
# 90 replaced: Eora ['伊欧拉'] ==> 艾欧拉
# 69 replaced: Eastern Reach ['伊斯特里奇'] ==> 艾欧拉东域
# 6 replaced: Free Palatinate ['自由领'] ==> 自治领
# 15 replaced: Cilant Lîs ['希兰特里斯'] ==> 锡兰尼斯
# 23 replaced: Valewood ['韦尔伍德'] ==> 谷林地
# 259 replaced: Gilded Vale ['丰饶之谷'] ==> 饰金谷
# 16 replaced: The Black Hound Inn ['黑猎犬旅店'] ==> 黑犬旅店
# 80 replaced: Temple of ['神殿'] ==> 神庙
# 1 replaced: Black Hammer Smithy ['黑锤铁匠铺'] ==> 黑锤铁铺
# 30 replaced: Raedric's Hold ['莱德里克的要塞'] ==> 瑞德利克堡
# 17 replaced: Esternwood ['伊斯特伍德'] ==> 东林地
# 18 replaced: Magran's Fork ['玛格岚岔口'] ==> 玛珈岚之叉
# 28 replaced: Black Meadow ['黑草甸'] ==> 黑草原
# 315 replaced: Caed Nua ['塞德努亚'] ==> 凯努亚
# 14 replaced: Madhmr Bridge ['马德米尔桥'] ==> 梅德慕桥
# 5 replaced: Aedelwan Bridge ['艾德尔万大桥'] ==> 艾迪万桥
# 55 replaced: First Fires ['最初之火'] ==> 火源
# 49 replaced: Crucible Keep ['炼狱堡垒'] ==> 坩埚堡
# 51 replaced: Ducal Palace ['公爵宫殿', '公爵宫', '公爵府', '伯爵宫殿', '伯爵宫', '伯爵大殿', '伯爵大厅'] ==> 公爵殿
# 12 replaced: Vailian Embassy ['维拉大使馆', '维拉使馆'] ==> 瓦利亚大使馆
# 98 replaced: Ondra's Gift ['昂德拉之地'] ==> 昂德拉赠礼
# 60 replaced: The Salty Mast ['盐柱'] ==> 咸桅杆
# 21 replaced: Vailian Trading Company ['维拉贸易公司', '维拉贸易行'] ==> 瓦利亚商行
# 1 replaced: Barnacle Row ['藤壶怒吼'] ==> 藤壶路
# 1 replaced: Seabreeze Row ['海风怒吼'] ==> 海风路
# 9 replaced: Brackenbury District ['布拉肯伯里区', '布拉肯伯里地区', '布拉肯伯里'] ==> 蕨葬区
# 137 replaced: Brackenbury ['布拉肯伯里'] ==> 蕨葬区
# 22 replaced: The Charred Barrel ['烧黑的木桶', '焦桶'] ==> 焦黑酒桶
# 91 replaced: Heritage Hill ['传承山'] ==> 遗产岭
# 11 replaced: Copperlane District ['铜径区', '铜径'] ==> 铜板巷
# 86 replaced: Copperlane ['科博莱茵', '铜径区', '铜径'] ==> 铜板巷
# 26 replaced: Hall of Revealed Mysteries ['揭秘堂', '揭秘大厅', '密室大厅'] ==> 显秘堂
# 5 replaced: Admeth's Den Expedition Hall ['艾德迈斯的巢穴', '艾德迈斯巢穴', '艾德迈斯巢穴远征大厅'] ==> 阿德玛斯的小窝
# 71 replaced: Catacombs ['地下墓穴'] ==> 墓穴
# 1 replaced: Scriveners Dormitory ['公证人宿舍'] ==> 书记员宿舍
# 30 replaced: Scrivener ['公证人'] ==> 书记员
# 16 replaced: Dracogen Inn ['德拉科根旅馆'] ==> 龙酿酒馆
# 3 replaced: Dyrford Mill ['迪福特磨坊'] ==> 鹿滩镇磨坊
# 4 replaced: Winfrith's Arms and Armory ['温弗里斯的兵械店'] ==> 温弗里斯军械店
# 8 replaced: Dyrford Crossing ['迪福特十字路口', '迪福特岔路'] ==> 鹿滩岔口
# 116 replaced: Dyrford ['迪福特'] ==> 鹿滩镇
# 1 replaced: Grisly Cave ['恐怖洞穴'] ==> 可怖的洞穴
# 1 replaced: Broken Statue ['破碎雕像'] ==> 损坏的雕像
# 24 replaced: Anslög's Compass ['安斯罗格海岸'] ==> 安索罗的指向针
# 41 replaced: Hearthsong ['炉火乐曲区', '炉火乐曲'] ==> 炉歌
# 1 replaced: Builders' Hearth ['创建者炉火'] ==> 筑者炉火
# 25 replaced: The Passage of the Six ['六圣通道', '六圣部落'] ==> 六部之道
# 5 replaced: Hearthsong Market ['炉火乐曲区市场', '炉歌市场'] ==> 炉歌市集
# 4 replaced: Oldsong District ['古乐曲区', '古老乐曲区'] ==> 遗颂区
# 41 replaced: Oldsong ['古乐曲区', '古老乐曲区'] ==> 遗颂
# 66 replaced: Noonfrost ['正午之霜'] ==> 午霜
# 20 replaced: Galawain's Maw ['加拉维恩无底洞'] ==> 伽拉温之胃
# 2 replaced: Hylea's Shrine ['海莉亚的神龛'] ==> 海丽娅神龛
# 11 replaced: Celestial Sapling ['天空之幼树', '天空树苗'] ==> 神树幼苗
# 40 replaced: Elms' Reach ['榆树之地'] ==> 榆林地
# 6 replaced: Hall of Warriors ['战士圣殿'] ==> 勇者之殿
# 43 replaced: Blood Sands ['血色沙漠'] ==> 血沙
# 67 replaced: Teir Evron ['泰尔埃弗隆'] ==> 群星之殿
# 44 replaced: Burial Isle ['安息岛'] ==> 葬仪岛
# 15 replaced: Woodend Plains ['林端平原'] ==> 滞林平原
# 9 replaced: Pearlwood Bluff ['珍珠林峭壁'] ==> 珍木崖
# 12 replaced: Stormwall Gorge ['风暴墙大峡谷'] ==> 风暴之墙峡谷
# 12 replaced: Searing Falls ['灼热瀑布'] ==> 陨星泉
# 41 replaced: Northweald ['北部旷野'] ==> 北旷野
# 12 replaced: Elmshore ['榆树海滨'] ==> 榆树滨
# 38 replaced: Clîaban Rilag ['卡里班利莱格'] ==> 卡利班里格
# 13 replaced: Lle a Rhemen ['楼丛', '楼从'] ==> 瑞阿内门
# 51 replaced: Great Hall ['宏伟大厅'] ==> 要塞大厅
# 38 replaced: The Abbey of the Fallen Moon ['坠月修道院', '落月修道院'] ==> 陨月修道院
# 4 replaced: Chamber of the Fallen Moon ['坠月之室', '坠月室'] ==> 陨月室
# 2 replaced: Hall of the Tidal Wave ['浪潮大厅'] ==> 浪潮厅
# 4 replaced: Halls of Presence ['存在之厅', '呈现之厅'] ==> 威仪厅
# 28 replaced: Halls of Silence ['寂静之厅', '沉默之厅', '无声神殿', '沉默大厅', '沉寂大厅'] ==> 静修堂
# 44 replaced: Whitestone Hollow ['白石之洞', '白石洞', '白岩洞'] ==> 白石湖
# 7 replaced: Iron Flail Fort ['链枷骑兵堡垒', '铁枷骑兵的堡垒'] ==> 铁枷营寨
# 58 replaced: Cayron's Scar ['凯龙的伤疤', '肯罗之疤', '凯龙断崖', '凯龙的断崖', '凯龙伤痕', '凯龙的伤痕'] ==> 星痕谷
# 4 replaced: Crägholdt Bluffs ['克雷格霍德断崖'] ==> 峭岩绝壁
# 23 replaced: Crägholdt ['克雷格霍德'] ==> 峭岩堡
# 810 replaced: Dyrwood ['迪伍德'] ==> 鹿林
# 7 replaced: New Yarma ['新亚尔马'] ==> 新雅玛
# 7 replaced: New Dunryd ['新顿瑞德'] ==> 新遁亚
# 6 replaced: Mercy Vale ['仁慈谷'] ==> 慈悲谷
# 41 replaced: New Heomar ['新希奥马'] ==> 新锡玛
# 315 replaced: Caed Nua ['塞德努亚', '塞德·努亚'] ==> 新锡玛
# 118 replaced: Od Nua ['奥德·努亚', '奥德努亚'] ==> 古努亚
# 12 replaced: Halgot Citadel ['哈尔格特城堡'] ==> 海歌特堡
# 3 replaced: Isce Uar ['伊斯乌尔河'] ==> 艾瑟乌尔河
# 7 replaced: Isce Îen ['伊斯瑟恩河', '伊斯瑟恩'] ==> 艾瑟茵恩河
# 9 replaced: Bael River ['巴埃尔河', '巴尔河'] ==> 木橘河
# 7 replaced: Loghome ['罗格霍姆'] ==> 原木居
# 7 replaced: Geiran's grasp ['戈兰之爪'] ==> 盖冉的攫取
# 7 replaced: Road's End ['路之尽头'] ==> 终途镇
# 16 replaced: Baelreach ['巴尔里奇'] ==> 橘临
# 3 replaced: Bael Marsh ['巴埃尔沼泽'] ==> 橘沼
# 173 replaced: Eir Glanfath ['伊尔格兰法斯', '格兰法斯国'] ==> 艾尔·格兰芬瑟
# 347 replaced: Glanfathan ['格兰法斯人'] ==> 格兰芬瑟人
# 474 replaced: Glanfath ['格兰法斯'] ==> 格兰芬瑟
# 4 replaced: Kindle Vale ['光明谷', '燃火河谷'] ==> 燃光谷
# 6 replaced: Solace Vale ['慰藉谷'] ==> 藉慰谷
# 1 replaced: Abbey of the Cloven Wheel ['裂轮寺院'] ==> 裂轮修道院
# 2 replaced: The court of bowing ashes ['灰土王宫', '灰土的法庭'] ==> 低墟庭
# 7 replaced: Ibrel's well ['伊博瑞尔之井'] ==> 贝瑞之井
# 4 replaced: Midwood ['米德伍德'] ==> 密林镇
# 94 replaced: Vailian Republics ['维拉共和国'] ==> 瓦利亚共和国
# 14 replaced: Ancenze ['安森斯'] ==> 安瑟泽
# 12 replaced: Ozia ['奥兹'] ==> 奥齐亚
# 6 replaced: Revua ['雷武亚'] ==> 瑞瓦
# 13 replaced: Selona ['赛罗纳'] ==> 瑟洛拿
# 6 replaced: Spirento ['斯派伦多', '斯派伦图'] ==> 斯庇伦托
# 1 replaced: Parchozzi ['帕索兹'] ==> 帕厝兹
# 260 replaced: Readcera ['里德赛拉斯'] ==> 瑞德赛拉斯
# 154 replaced: Readceran ['里德赛拉斯'] ==> 瑞德赛拉斯
# 126 replaced: Readceras ['里德赛拉斯'] ==> 瑞德赛拉斯
# 12 replaced: Halgot Citadel ['哈尔格特城堡'] ==> 海歌特堡
# 8 replaced: Godhammer Citadel ['圣锤堡'] ==> 神锤堡
# 136 replaced: the White March ['苍运高原', '苍运国', '苍运'] ==> 白际山脉
# 175 replaced: White March ['苍运高原', '苍运国', '苍运'] ==> 白际山
# 258 replaced: Durgan's Battery ['矮人军械所'] ==> 锻钢要塞
# 66 replaced: The Mines ['矿场', '矿井', '矿山'] ==> 采矿场
# 40 replaced: Cold Morn ['寒晓', '寒晓镇镇'] ==> 寒晓镇
# 168 replaced: White Forge ['白色锻炉', '白色熔炉', '苍运锻炉', 'WhiteForge'] ==> 白铸炉
# 486 replaced: Stalwart ['斯图瓦特', '斯图尔特'] ==> 坚忍村
# 24 replaced: Longwatch Falls ['瞩望瀑布'] ==> 远望瀑布
# 58 replaced: Russetwood ['赤褐森林'] ==> 褐叶林
# 4 replaced: Gref's rest ['侯爵旅馆'] ==> 总督居
# 58 replaced: Fishery ['鱼铺'] ==> 渔场
# 6 replaced: Maiden Falls ['少女之陨'] ==> 少女泉
# 30 replaced: Thein ['泰恩', '塞恩'] ==> 瑟因
# 22 replaced: Thein Bog ['泰恩沼泽'] ==> 瑟因沼泽
# 4 replaced: Airana's tears ['艾拉娜眼泪', '艾拉娜之泪'] ==> 艾莲娜之泪
# 6 replaced: Lake of drowned tombs ['浸没墓穴的湖泊'] ==> 沉墓之湖
# 4 replaced: The Pearl Coast ['珍珠海岸'] ==> 珍珠岸
# 5 replaced: Pearlwood Gulf ['珀伍德湾', '珀伍德海湾'] ==> 珍木湾
# 4 replaced: Telaneir ['塔拉尼尔'] ==> 塔兰尼尔
# 4 replaced: Madsdam ['马斯达姆'] ==> 梅德黛
# 25 replaced: Aedyr Empire ['鹿丛帝国'] ==> 聚鹿帝国
# 48 replaced: Deadfire Archipelago ['亡焰群岛'] ==> 亡焰列岛
# 1 replaced: Restless Ocean ['不息洋'] ==> 无静海
# 52 replaced: Naasitaq ['纳斯塔克'] ==> 纳斯塔寇
# 15 replaced: Ixamitl Plains ['以撒弥陀平原'] ==> 以撒密陀平原
# 152 replaced: Rauatai ['劳亚泰'] ==> 奴瓦泰
# 21 replaced: Tâkowa ['塔科瓦'] ==> 塔科瓦
# 52 replaced: The Living Lands ['活化之地'] ==> 盎然之地
# 40 replaced: The White that Wends ['白茫冰地'] ==> 若移冰地
# 48 replaced: Old Vailia ['前维拉'] ==> 旧瓦利亚
# 298 replaced: Vailian ['维拉'] ==> 瓦利亚
# ===patch end
# ===strat replace
# 34 replaced: Phrase ['祷词'] ==> 乐节
# 18 replaced: Invocation ['祷言'] ==> 祷歌
# 582 replaced: Raw ['纯粹'] ==> 真实
# 49 replaced: Slash ['挥砍', '斩击'] ==> 挥砍
# 41 replaced: Piercing ['刺穿'] ==> 穿刺
# 75 replaced: Pierce ['刺穿'] ==> 穿刺
# 27 replaced: Crushing ['粉碎'] ==> 钝击
# 110 replaced: Crush ['粉碎'] ==> 钝击
# 121 replaced: Shock ['电击'] ==> 电击
# 470 replaced: Burn ['燃烧'] ==> 灼烧
# 89 replaced: Freeze ['冰冻'] ==> 冰冻
# 34 replaced: Corrode ['腐蚀'] ==> 腐蚀
# 68 replaced: Afflictions ['痛苦效果', '减益效果', '负面效果'] ==> 负面状态
# 34 replaced: Blinded ['致盲'] ==> 目盲
# 24 replaced: Charmed ['魅惑'] ==> 魅惑
# 65 replaced: Confused ['困惑'] ==> 困惑
# 28 replaced: Dazed ['晕眩'] ==> 晕眩
# 35 replaced: Dominated ['控制'] ==> 宰制
# 30 replaced: Flanked ['夹击'] ==> 夹击
# 49 replaced: Frightened ['受惊'] ==> 惊慌
# 32 replaced: Hobbled ['迟缓'] ==> 蹒跚
# 21 replaced: Maimed ['重伤'] ==> 残废
# 27 replaced: Paralyzed ['麻痹'] ==> 麻痹
# 31 replaced: Petrified ['石化'] ==> 石化
# 67 replaced: Prone ['倒地'] ==> 倒地
# 24 replaced: Sickened ['恶心', '患病', '得病'] ==> 恶心
# 130 replaced: Stuck ['被困'] ==> 缚足
# 40 replaced: Stunned ['震慑', '眩晕', '震惊'] ==> 震慑
# 31 replaced: Terrified ['恐惧'] ==> 恐惧
# 44 replaced: Weakened ['虚弱'] ==> 虚弱
# 55 replaced: Unconscious ['昏迷'] ==> 昏迷
# 34 replaced: Distracted ['分心'] ==> 烦乱
# 3 replaced: Severe Wound ['重伤'] ==> 垂死
# 4 replaced: Strange Illness ['奇异病症0'] ==> 怪病
# 3 replaced: Bruised Ribs ['肋骨挫伤'] ==> 胸肋受创
# 3 replaced: Concussion ['震荡'] ==> 脑部震荡
# 3 replaced: Sprained Wrist ['手腕扭伤'] ==> 腕节扭伤
# 3 replaced: Swollen Eye ['眼睛浮肿'] ==> 眼部浮肿
# 3 replaced: Twisted Ankle ['脚踝扭伤'] ==> 踝节扭伤
# 3 replaced: Wrenched Knee ['膝盖扭伤'] ==> 膝盖扭伤
# 5 replaced: Wrenched Shoulder ['肩膀扭伤'] ==> 肩部扭伤
# 2 replaced: Severe Burn ['重度烧伤'] ==> 重度烧伤
# 5 replaced: Frostbite ['冻伤', '霜寒啃咬'] ==> 重度冻伤
# 2 replaced: System Shock ['系统电击'] ==> 肢体麻木
# 3 replaced: Severe Wound ['重伤'] ==> 严重创伤
# ===patch end
# ===strat replace
# 393 replaced: Beast ['野兽'] ==> 野兽
# 202 replaced: Stelgaer ['蝎虎狮'] ==> 狮尾虎
# 2 replaced: Elder Bear ['年长熊'] ==> 巨熊
# 4 replaced: Elder Boar ['年长野猪'] ==> 壮猪
# 5 replaced: Elder Lion ['年长狮子'] ==> 雄狮
# 2 replaced: Elder Stelgaer ['年长蝎虎狮', '蝎虎狮'] ==> 厉狮尾虎
# 2 replaced: Elder Wolf ['年长狼', '老狼'] ==> 苍狼
# 2 replaced: Elder Antelope ['年长羚羊', '羚羊'] ==> 巨羚
# 2 replaced: Elder Stag ['年长牡鹿', '牡鹿'] ==> 大牡鹿
# 313 replaced: Dragon ['恐龙'] ==> 龙
# 66 replaced: Drake ['伪龙'] ==> 龙兽
# 51 replaced: Wurm ['亚龙'] ==> 伪龙
# 2 replaced: Wurmling ['小亚龙', '小伪龙'] ==> 幼伪龙
# 3 replaced: Crystal Eater ['水晶吞噬者'] ==> 噬晶蛛
# 1 replaced: Crystal Eater Spiderling ['水晶吞噬者幼蛛'] ==> 噬晶幼蛛
# 3 replaced: Ivory Spinner ['象牙吐丝者'] ==> 牙色织网蛛
# 12 replaced: Moon Spider ['月蜘蛛'] ==> 月魔蛛
# 2 replaced: Moon Spiderling ['小月蜘蛛'] ==> 月魔幼蛛
# 13 replaced: Spear Spider ['矛蜘蛛'] ==> 利矛蛛
# 1 replaced: Spear Spiderling ['幼矛蛛'] ==> 利矛幼蛛
# 3 replaced: Spider Queen ['蜘蛛女王', '蜘蛛女皇'] ==> 蛛后
# 9 replaced: Widowmaker ['寡妇制造者'] ==> 寡妇蛛
# 4 replaced: Widowmaker Spiderling ['寡妇制造者幼蛛'] ==> 寡妇幼蛛
# 130 replaced: Wilder ['魔兽'] ==> 魔物
# 32 replaced: Crag Ogre ['峭壁食人魔'] ==> 碎岩食人魔
# 57 replaced: Skuldrak ['史库莱克'] ==> 冰蝠魔
# 2 replaced: Vithrack Luminary ['蛛人菁英'] ==> 幽光蛛人
# 2 replaced: Vithrack Brute ['蛛人强壮者'] ==> 蛮暴蛛人
# 109 replaced: Xaurip ['蛇蜥人'] ==> 蜥人
# 10 replaced: Kraken ['海妖', '北海巨妖', 'Kraken'] ==> 克拉肯
# 4 replaced: lagufaeth redfin ['拉古法斯红鳍'] ==> 红鳍鱼人
# 2 replaced: lagufaeth barbarian ['拉古法斯野蛮人'] ==> 狂暴鱼人
# 2 replaced: lagufaeth broodmother ['拉古法斯育母'] ==> 巢母鱼人
# 2 replaced: lagufaeth sidewinder ['拉古法斯响尾蛇'] ==> 钉刺鱼人
# 2 replaced: lagufaeth cipher ['拉古法斯灵能师'] ==> 灵能鱼人
# 120 replaced: Lagufaeth ['拉古法斯人', '拉古法斯'] ==> 鱼人
# 14 replaced: Primordial ['原生物'] ==> 原生物
# 12 replaced: Sporeling ['小孢子'] ==> 幼菌怪
# 17 replaced: Dank Spore ['潮湿孢子'] ==> 湿菌怪
# 32 replaced: Radiant Spore ['发光孢子'] ==> 辐光菌怪
# 2 replaced: Radiant Sporeling ['发光小孢子'] ==> 辐光幼菌怪
# 3 replaced: Swamp Spore ['沼泽孢子'] ==> 沼泽菌怪
# 2 replaced: Death Spores ['死亡孢子'] ==> 死亡菌怪
# 100 replaced: Spore ['孢子'] ==> 菌怪
# 49 replaced: Delemgan ['叶精'] ==> 树妖
# 10 replaced: Adragan ['绿萤裔'] ==> 魂珀妖
# 21 replaced: Pŵgra ['叶魔'] ==> 腐妖
# 23 replaced: Lurker ['潜伏者'] ==> 潜妖
# 40 replaced: Ooze ['泥怪'] ==> 软泥怪
# 538 replaced: Spirit ['灵魂'] ==> 灵体
# 81 replaced: Blight ['丧魂'] ==> 魂怪
# 15 replaced: Cean Gŵla ['血妖'] ==> 血女
# 8 replaced: Siren ['女妖'] ==> 女妖
# 25 replaced: Phantom ['幻影0'] ==> 幽魂
# 11 replaced: Spectre ['幽鬼'] ==> 幽鬼
# 239 replaced: Shadow ['幽鬼'] ==> 暗影
# 9 replaced: Wraith ['缚灵'] ==> 恶灵
# 124 replaced: Vessel ['躯壳'] ==> 魂躯
# 4 replaced: Animated Weapon ['活体武器'] ==> 活化武器
# 24 replaced: Animated ['灵动', '活体'] ==> 活化
# 4 replaced: Adra Animat ['绿萤灵魂机甲', '绿萤石灵魂胸甲'] ==> 魂珀甲
# 64 replaced: Animat ['灵魂机甲', '灵魂胸甲'] ==> 魂甲
# 11 replaced: Flesh Construct ['肉身构造体', '血肉构装生物'] ==> 血肉构装体
# 2 replaced: Unstable Construct ['不稳定的构装生物'] ==> 不稳定构装体
# 150 replaced: Construct ['构造体', '构装生物'] ==> 构装体
# 2 replaced: Battery Guards ['军械库守卫'] ==> 锻钢卫士
# 4 replaced: Battery Shieldwall ['军械所盾墙'] ==> 锻钢盾卫
# 4 replaced: Battery Defender ['军械所卫士'] ==> 锻钢护卫
# 2 replaced: Battery Priest ['军械所牧师'] ==> 锻钢牧师
# 2 replaced: Battery Sharpshooter ['军械所神射手'] ==> 锻钢神射手
# 11 replaced: Forge Guardian ['锻炉守卫'] ==> 铸铁卫
# 6 replaced: Death Guard ['死亡护卫'] ==> 死亡守卫
# 189 replaced: Eyeless ['无目', '无眼者'] ==> 目无
# 2 replaced: Eyeless Hammer ['无目锤手'] ==> 无眼震地者
# 2 replaced: Eyeless Stonepiercer ['无目穿石者'] ==> 无眼穿石者
# 11 replaced: Fampyrs ['近亡者'] ==> 吸血鬼
# 9 replaced: Darguls ['半亡者'] ==> 食尸鬼
# 20 replaced: Guls ['亡者'] ==> 尸鬼
# 5 replaced: Algul ['妖魔', 'Algul'] ==> 尸妖
# 5 replaced: Revenant ['亡魂'] ==> 行尸
# 30 replaced: phylactery ['经匣'] ==> 命匣
# 4 replaced: Void Seer ['虚无贤者0'] ==> 虚空之颅
# 23 replaced: Maegfolc ['大力神'] ==> 巨怪
# ===patch end
# ===strat replace
# ===patch end
# ===strat replace
# 397 replaced: Adra ['绿萤'] ==> 魂珀
# 1 replaced: Wyflan steel ['韦弗兰钢'] ==> 怀弗兰钢
# 25 replaced: March steel ['进击钢铁', '苍运钢'] ==> 白际钢
# 2 replaced: Ymyran steel ['伊米尔钢'] ==> 鑫兰钢
# 44 replaced: Durgan steel ['矮人钢铁', '矮人钢', '矮人兵器', '矮人制钢'] ==> 煅钢
# 3 replaced: Copper Pand ['铜板币', '铜币'] ==> 铜板
# 2 replaced: Copper Skeyt ['铜钱币', '铜币'] ==> 铜钱
# 1 replaced: Copper Awld ['粗糙铜币'] ==> 铜结
# 2 replaced: Silver Lusce ['银鱼币'] ==> 银鱼
# 1 replaced: Silver Fenning ['银溏币'] ==> 银玢
# 1 replaced: Golden Suole ['金太阳币'] ==> 金阳
# 5 replaced: Golden Duc ['金公爵币'] ==> 金爵
# 1 replaced: Golden Scelling ['金鳞币'] ==> 金貝
# 2 replaced: Golden Oble ['金双币'] ==> 金重币
# 0 replaced: Adra Eniach ['绿萤勋币', '魂珀勋币'] ==> 珀碟
# 2 replaced: Readceran Skeyt ['里德赛拉斯钱币', '瑞德赛拉斯铜钱'] ==> 瑞德赛铜钱
# 4 replaced: Readceran Fenning ['里德赛拉斯溏币', '瑞德赛拉斯银玢'] ==> 瑞德赛银玢
# 2 replaced: Stalwart Boney ['斯图尔特骨'] ==> 坚忍村骨元
# 2 replaced: Admeth's Wyrt ['艾德迈斯花', '艾德玛斯花'] ==> 艾棯
# 2 replaced: Berath's Bell ['贝拉斯之铃'] ==> 贝拉斯之铃
# 1 replaced: Burned Lady ['焦女菇'] ==> 焦燃女士
# 2 replaced: Brintwn Ban ['布林特禁令'] ==> 白绒
# 3 replaced: Cave Coral ['洞穴珊瑚虫', '洞穴珊瑚'] ==> 穴珊瑚
# 7 replaced: Dyrcap ['迪菇'] ==> 鹿盖菇
# 2 replaced: Golden Celery ['金色芹菜'] ==> 金芹
# 1 replaced: Orlan's Cradle ['羽精的摇篮'] ==> 绒精摇篮
# 2 replaced: Pilgrim's Crown ['朝圣者的王冠'] ==> 朝圣冕
# 11 replaced: River Reed ['河畔芦苇'] ==> 河苇
# 2 replaced: Ryngr Berries ['莱格里姆浆果'] ==> 游侠莓
# 1 replaced: Settler's Arrow ['殖民者的箭'] ==> 殖民者之箭
# 3 replaced: Skaenbone ['奴仆菇'] ==> 司坎之骨
# 3 replaced: Springberry ['浆果'] ==> 春莓
# 0 replaced: St Gyran's Horn ['圣吉兰的角'] ==> 圣吉岚的号角
# 4 replaced: Tyn Hat ['小阳帽'] ==> 锡帽菇
# 17 replaced: Vorlas ['沃拉思'] ==> 紫金草
# 1 replaced: Adra Dragon Scale ['绿萤龙鳞片'] ==> 魂珀龙鳞
# 1 replaced: Awakened Wood ['唤醒的树木'] ==> 觉醒木
# 1 replaced: Awakened Adra ['觉醒的绿萤'] ==> 觉醒珀
# 1 replaced: Awakened Root ['唤醒的树根'] ==> 觉醒根
# 8 replaced: Beetle Shell ['甲虫壳'] ==> 甲壳
# 8 replaced: Dank Spores ['潮湿孢子'] ==> 湿孢子
# 1 replaced: Drake Talon ['伪龙爪'] ==> 亚龙爪
# 3 replaced: Ogre Blood ['食人魔之血'] ==> 食人魔血
# 1 replaced: Ooze Plasma ['泥怪血浆'] ==> 泥怪细胞
# 1 replaced: Primal Flame ['原始火焰'] ==> 焰精魂
# 1 replaced: Primal Rock ['原始岩石'] ==> 岩精魂
# 1 replaced: Primal Water ['原始水'] ==> 水精魂
# 1 replaced: Primal Wind ['原始风'] ==> 风精魂
# 2 replaced: Skuldr Ear ['蝠魔之耳'] ==> 蝠魔耳
# 2 replaced: Sky Dragon Eye ['天龙眼'] ==> 天龙眼
# 1 replaced: Spear Spider Leg ['矛蜘蛛腿'] ==> 利矛蜘蛛脚
# 1 replaced: Spirit Residue ['灵魂残留'] ==> 灵体残余
# 2 replaced: Stelgaer Tooth ['蝎虎狮牙齿'] ==> 狮尾虎齿
# 4 replaced: Troll Skin ['巨魔皮肤'] ==> 巨魔皮
# 3 replaced: Vessel Bone ['躯壳的骨头'] ==> 魂躯的骨骼
# 1 replaced: Vessel Flesh ['躯壳的肉体'] ==> 魂躯的血肉
# 1 replaced: Vithrack Brain ['蛛人之脑'] ==> 蛛人脑
# 1 replaced: Wurm Wing ['亚龙之翼'] ==> 幼龙翼
# 2 replaced: Xaurip Tongue ['蛇蜥人的舌头'] ==> 蜥人舌
# 29 replaced: Bloodstone ['血石'] ==> 血石
# 397 replaced: Adra ['绿萤'] ==> 魂珀
# 0 replaced: Adra Bán ['白曜石'] ==> 魂晶
# 5 replaced: Agate ['玛瑙石'] ==> 玛瑙
# 3 replaced: Amethyst ['紫水晶'] ==> 紫晶
# 8 replaced: Emerald ['绿宝石'] ==> 祖母绿
# 2 replaced: Garnet ['幽红石'] ==> 石榴石
# 3 replaced: Jasper ['碧玉石'] ==> 墨玉
# 5 replaced: Moonstone ['月石'] ==> 月长石
# 19 replaced: Opal ['彩虹石'] ==> 猫眼石
# 15 replaced: Peridot ['橄榄石'] ==> 橄榄石
# 0 replaced: Ta ondra tara ['白晶石'] ==> 昂德拉之牙
# 2 replaced: Topaz ['黄玉石'] ==> 晶玉
# 4 replaced: Turquoise ['绿松石'] ==> 绿松石
# 2 replaced: Velune ['杏石'] ==> 薇露晶
# 7 replaced: Blacsonn ['布拉科森'] ==> 贝松(酒)
# 11 replaced: Carow Golan ['卡洛格兰'] ==> 喀柔浆
# 53 replaced: Svef ['迷草'] ==> 幻叶果
# 12 replaced: Whiteleaf ['白叶'] ==> 白叶
# 10 replaced: Snowcap ['雪菇'] ==> 雪盖菇
# 6 replaced: Goldrot Chew ['香口胶'] ==> 金须胶
# 13 replaced: Ripple Sponge ['波纹海绵'] ==> 涟绵粉
# 3 replaced: Mocga's Tears ['莫克加的眼泪', '莫克加眼泪'] ==> 陌佳之泪
# 5 replaced: sonnread ['森里德'] ==> 松梅(酒)
# 4 replaced: Bitter spirit ['苦难灵魂', '充满敌意的灵魂', '充满敌意的灵体'] ==> 苦灵(酒)
# 16 replaced: speckleback ['Speckleback', '背斑鱼'] ==> 斑背鱼
# 3 replaced: irontooth pike ['铁牙枪鱼'] ==> 钢齿梭
# 2 replaced: frostdiver fish ['霜潜鱼'] ==> 霜跃鱼
# ===patch end
# ===strat replace
# 762 replaced: Might ['之力量', '力量'] ==> 威力
# 28 replaced: Constitution ['之体质'] ==> 体质
# 35 replaced: Dexterity ['之敏捷'] ==> 敏捷
# 59 replaced: senses ['感知'] ==> 感官
# 40 replaced: Perception ['洞察力', '之直觉', '直觉'] ==> 感知
# 34 replaced: Intellect ['之智力'] ==> 智力
# 108 replaced: Resolve ['之决断', '决断'] ==> 决心
# 94 replaced: Deflection ['偏转'] ==> 格挡
# 24 replaced: Stealth ['潜行'] ==> 隐匿
# 200 replaced: Lore ['博学'] ==> 学识
# 20 replaced: Mechanics ['机械学', '机械'] ==> 器械
# 43 replaced: Aggressive ['攻击性'] ==> 莽撞
# 6 replaced: Benevolent ['仁慈'] ==> 善良
# 60 replaced: Clever ['机智'] ==> 机灵
# 90 replaced: Cruel ['残酷'] ==> 残忍
# 7 replaced: Deceptive ['欺骗'] ==> 欺骗
# 4 replaced: Diplomatic ['交涉'] ==> 世故
# 102 replaced: Honest ['诚实'] ==> 坦诚
# 16 replaced: Passionate ['激昂'] ==> 热血
# 11 replaced: Rational ['理性'] ==> 理智
# 10 replaced: Stoic ['淡泊'] ==> 冷淡
# 2 replaced: West Curtain Wall ['西方幕墙'] ==> 西护墙
# 2 replaced: South Curtain Wall ['南方幕墙'] ==> 南护墙
# 10 replaced: Eastern Barbican ['东方瓮城'] ==> 东门楼
# 3 replaced: Western Barbican ['西方瓮城'] ==> 西门楼
# 2 replaced: Main Keep ['主堡垒'] ==> 主堡
# 51 replaced: Great Hall ['宏伟大厅'] ==> 主厅
# 8 replaced: Barracks ['兵营'] ==> 军营
# 4 replaced: Craft Hall ['锻治大厅'] ==> 锻冶厅
# 7 replaced: Artificer's Hall ['技师大厅'] ==> 创造厅
# 5 replaced: Forum ['广场', '会议所'] ==> 评议区
# 3 replaced: Merchant Stalls ['商人摊位'] ==> 商贩摊位
# 7 replaced: Curio Shop ['古玩店'] ==> 古董店
# 20 replaced: Chapel ['小教堂', '礼拜堂'] ==> 教堂
# 6 replaced: Hedge Maze ['篱笆迷宫'] ==> 树篱迷宫
# 4 replaced: Botanical Garden ['植物园'] ==> 种植园
# 7 replaced: Warden's Lodge ['守望者小屋'] ==> 看守小屋
# 4 replaced: Woodland Trails ['林地小路', '森林小径'] ==> 林中小径
# 124 replaced: Aumaua ['奥玛人'] ==> 海裔
# 5 replaced: Coastal Aumaua ['沿海海裔'] ==> 沿岸海裔
# 5 replaced: Island Aumaua ['岛屿海裔'] ==> 列岛海裔
# 5 replaced: Boreal Dwarves ['冰原矮人'] ==> 寒地矮人
# 4 replaced: Enutanik ['伊努塔尼克'] ==> 恩努塔尼克人
# 2 replaced: Mountain Dwarves ['高山矮人'] ==> 山地矮人
# 8 replaced: Aptapo ['埃普塔伯'] ==> 艾塔波人
# 66 replaced: Pargrunen ['帕格鲁矮人', '帕格伦恩', '帕格伦恩人', '帕格伦矮人', '帕格卢宁', '帕格鲁', '帕格伦', 'Pargrunen'] ==> 旅矮人
# 36 replaced: Pale Elves ['白精灵'] ==> 苍精灵
# 22 replaced: Glamfellen ['格拉姆费伦', '格拉姆法伦'] ==> 格兰费伦人
# 1 replaced: Sceltrfolc ['斯塞切弗克'] ==> 赛特洛孚人
# 3 replaced: Nature godlike ['自然神民'] ==> 自然神嗣
# 3 replaced: Death godlike ['死亡神民'] ==> 死神嗣
# 2 replaced: Avian godlike ['鸟之神民', '鸟类神民'] ==> 翼神嗣
# 3 replaced: Moon godlike ['皎月神民'] ==> 月神嗣
# 3 replaced: Fire godlike ['火焰神民'] ==> 火神嗣
# 33 replaced: Godlike ['神民'] ==> 神嗣
# 3 replaced: Meadow Folk ['牧人'] ==> 游牧民族
# 2 replaced: Thyrtan ['塞尔坦人'] ==> 提坦人
# 2 replaced: Ocean Folk ['海民'] ==> 海洋民族
# 2 replaced: Savannah Folk ['草民'] ==> 草原民族
# 4 replaced: Hearth Orlan ['炉火羽精', '炉火绒精'] ==> 家绒精
# 6 replaced: Wild Orlan ['荒野羽精', '野蛮羽精'] ==> 野绒精
# 319 replaced: Orlan ['羽精', '奥兰人'] ==> 绒精
# 101 replaced: Chanter ['吟唱者', '诗人'] ==> 咏者
# 142 replaced: Cipher ['灵能师'] ==> 译灵使
# 136 replaced: Monk ['僧侣'] ==> 武僧
# 201 replaced: Wizard ['巫师'] ==> 法师
# 4376 replaced: DR ['伤害减免'] ==> DR
# 1 replaced: Dmg. Red. ['伤害减免'] ==> 伤害减免
# 158 replaced: Accuracy ['命中率', '精确度', '精度'] ==> 精准度
# 874 replaced: Acc ['命中率'] ==> 精准度
# 873 replaced: Acc. ['命中率'] ==> 精准度
# 954 replaced: Hit ['命中'] ==> 击中
# ===patch end
# ===strat replace
# 471 replaced: fine ['精致'] ==> 精良
# 64 replaced: Exceptional ['独特'] ==> 卓越
# 10 replaced: superb ['华丽', '超强品质'] ==> 超凡
# 10 replaced: Extraordinary ['超凡'] ==> 非凡
# 14 replaced: Hunting bow ['猎弓'] ==> 猎弓
# 16 replaced: War bow ['战弓'] ==> 战弓
# 27 replaced: Crossbow ['弩'] ==> 弩
# 10 replaced: Arbalest ['劲弩'] ==> 劲弩
# 1 replaced: Blunderbusse ['喇叭枪'] ==> 火铳
# 2 replaced: Pistols ['手枪'] ==> 手枪
# 6 replaced: Arquebuse ['火绳枪'] ==> 火绳枪
# 147 replaced: Wand ['魔杖'] ==> 魔杖
# 98 replaced: Scepter ['权杖'] ==> 权杖
# 219 replaced: Rod ['魔棒'] ==> 长杖
# 64 replaced: Club ['棍棒'] ==> 棍棒
# 160 replaced: Dagger ['匕首'] ==> 匕首
# 109 replaced: Flail ['连枷'] ==> 链枷
# 29 replaced: Rapier ['细剑'] ==> 细剑
# 19 replaced: Hatchet ['短柄斧'] ==> 手斧
# 32 replaced: Stiletto ['锥剑'] ==> 锥刺
# 10 replaced: Battle axe ['战斧'] ==> 战斧
# 84 replaced: Mace ['钉头锤'] ==> 战槌
# 22 replaced: Sabre ['马刀', '军刀'] ==> 弯刀
# 1 replaced: Light Spear ['轻矛'] ==> 轻矛
# 118 replaced: Spear ['长矛'] ==> 短矛
# 262 replaced: Sword ['剑'] ==> 剑
# 7 replaced: War hammer ['战锤'] ==> 战锤
# 56 replaced: Estoc ['破甲重剑'] ==> 长剑
# 14 replaced: Great sword ['巨剑'] ==> 巨剑
# 16 replaced: Morning star ['流星锤'] ==> 钉头槌
# 62 replaced: Pike ['战枪'] ==> 长矛
# 10 replaced: Pollaxe ['长柄战斧'] ==> 斧锤
# 17 replaced: Quarterstaff ['长棍'] ==> 手杖
# 2 replaced: Cloth Armor ['布甲'] ==> 布甲
# 8 replaced: Leather Armor ['皮甲'] ==> 革甲
# 7 replaced: Hide Armor ['厚皮甲', '厚革甲'] ==> 皮甲
# 5 replaced: Mail Armor ['锁子甲'] ==> 锁甲
# 7 replaced: Padded Armor ['絮甲'] ==> 绵甲
# 19 replaced: Plate Armor ['板甲'] ==> 板甲
# 12 replaced: Scale Armor ['鳞甲'] ==> 鳞甲
# 9 replaced: Brigandine ['镶甲'] ==> 甲衫
# 61 replaced: Breastplate ['胸甲'] ==> 胸甲
# 162 replaced: Spellbind ['法术绑定', '法术附着'] ==> 附带技能
# 29 replaced: Spell Holding ['法术持续'] ==> 重击回应
# 60 replaced: Spellchance ['法术命中率'] ==> 几率触发
# 19 replaced: Spell Striking ['法术攻击', '打击法术'] ==> 重击触发
# 18 replaced: Spellstamina ['法术耐力'] ==> 血限触发
# 16 replaced: Soulbound ['灵魂绑定'] ==> 灵魂绑定
# ===patch end
# ===strat replace
# 210 replaced: Aloth ['亚洛斯'] ==> 阿洛斯
# 47 replaced: Iselmyr ['伊瑟梅尔'] ==> 伊莎弥儿
# 1 replaced: Durant ['杜兰斯'] ==> 杜兰特
# 132 replaced: Edér ['艾德', '艾德尔尔'] ==> 艾德尔
# 86 replaced: Grieving Mother ['哀伤之母'] ==> 伤悲之母
# 230 replaced: Hiravias ['希拉维亚斯'] ==> 席拉维亚斯
# 29 replaced: Kana Rua ['卡纳·鲁亚'] ==> 卡纳·鲁阿
# 15 replaced: Ranga nui ['兰加努伊', '兰加·nui'] ==> 兰佳努伊
# 1 replaced: Tella Pallegina ['泰拉·帕勒吉娜'] ==> 泰拉·帕吉娜
# 217 replaced: Pallegina ['帕勒吉娜'] ==> 帕吉娜
# 137 replaced: Sagani ['莎加妮'] ==> 萨佳妮
# 67 replaced: Itumaak ['伊图马克'] ==> 伊图马克
# 11 replaced: Kallu ['卡鲁'] ==> 卡鲁
# 79 replaced: Persoq ['珀索克'] ==> 柏索克
# 3 replaced: Malaak ['莫拉克'] ==> 马拉克
# 3 replaced: Najuo ['拿朱'] ==> 拿乔
# 3 replaced: Yakona ['雅库娜'] ==> 亚阔娜
# 69 replaced: Devil of Caroc ['卡拉克的魔鬼', '卡拉克的恶魔', '卡拉克恶魔', '卡罗魔鬼', 'DevilofCaroc'] ==> 卡洛克恶魔
# 74 replaced: Caroc ['Caroc', '卡拉克'] ==> 卡洛克
# 157 replaced: Zahua ['扎哈'] ==> 扎华
# 100 replaced: Maneha ['玛娜哈0'] ==> 莫内哈
# 14 replaced: St. Waidwen ['圣人维德文', '圣维德文'] ==> 圣维德温
# 162 replaced: Waidwen ['维德文'] ==> 维德温
# 5 replaced: St. Elcga ['圣依尔佳', '依尔佳'] ==> 圣伊尔佳
# 22 replaced: Pandgram ['潘德格拉姆'] ==> 潘哲拉姆
# 69 replaced: Helig ['海利格'] ==> 赫里格
# 22 replaced: Admeth Hadret ['艾德迈斯·哈德雷特'] ==> 艾德玛斯·哈德莱特
# 9 replaced: Edrang Hadret ['埃德朗·哈德雷特'] ==> 艾德朗·哈德莱特
# 12 replaced: Edrang ['埃德朗'] ==> 艾德朗
# 49 replaced: Admeth ['艾德迈斯'] ==> 艾德玛斯
# 86 replaced: Hadret ['哈德雷特'] ==> 哈德莱特
# 7 replaced: Galven Regd ['可汗雷德'] ==> “燕雀”黎德
# 3 replaced: Galven Medhra ['可汗梅德拉'] ==> “燕雀”梅德拉
# 9 replaced: Mocga ['莫克加'] ==> 陌佳
# 5 replaced: Erol of Levi ['莱维的埃罗尔'] ==> 列维的埃罗尔
# 18 replaced: Ryona ['瑞欧娜'] ==> 萝欧娜
# 225 replaced: Gathbin ['加斯宾'] ==> 贾思彬
# 2 replaced: Ungradr ['拜戈拉德'] ==> 恩寡德
# 1 replaced: Manhem ['曼赫姆'] ==> 曼亨
# 15 replaced: Thaos ix Arkannon ['赛奥斯·阿坎诺'] ==> 撒奥斯·壹·阿坎农
# 354 replaced: Thaos ['赛奥斯', '塞奥斯'] ==> 撒奥斯
# 3 replaced: Iovara ix Ensios ['伊奥瓦拉·恩西欧斯'] ==> 依欧瓦拉·壹·恩希欧斯
# 64 replaced: Iovara ['伊奥瓦拉'] ==> 依欧瓦拉
# 123 replaced: Maerwald ['马尔瓦德'] ==> 梅沃德
# 25 replaced: Duc Aevar ['埃瓦尔公爵'] ==> 埃瓦公爵
# 5 replaced: Adaryc Cendamyr ['艾达瑞克森德米尔', '艾达瑞克·森德米尔'] ==> 厄达克·森德米尔
# 34 replaced: Odema ['奥德马'] ==> 奥德玛
# 48 replaced: Heodan ['希奥丹'] ==> 席欧丹
# 46 replaced: Calisca ['卡莉丝卡', '卡莉斯卡'] ==> 卡莉莎
# 18 replaced: Sparfel ['斯帕费尔'] ==> 斯帕伏
# 357 replaced: Raedric ['莱德里克'] ==> 瑞德利克
# 4 replaced: Caldara de Berranzi ['卡尔达拉·德·贝朗兹', '卡尔达拉·贝朗兹'] ==> 卡达菈·德·贝兰茨
# 115 replaced: Kolsc ['寇尔什'] ==> 寇沙
# 55 replaced: Aufra ['欧弗拉'] ==> 埃芙拉
# 28 replaced: Tuatanu ['图阿塔努'] ==> 图塔努
# 101 replaced: Wirtan ['维尔坦'] ==> 维尔坦
# 60 replaced: Ranga ['兰加'] ==> 兰佳
# 67 replaced: Trumbel ['特鲁梅贝尔', '特鲁姆贝尔'] ==> 塔贝尔
# 1 replaced: Ufdaen ['乌弗丹'] ==> 厄夫丹
# 1 replaced: Cearu ['希亚鲁'] ==> 赛鲁
# 21 replaced: Tenfrith ['坦弗里斯'] ==> 腾弗里斯
# 63 replaced: Sweynur ['斯维努尔'] ==> 斯维勒
# 1 replaced: Gafwen ['加弗温'] ==> 加夫温
# 1 replaced: Brethan ['布雷桑'] ==> 贝瑞坦
# 7 replaced: Tana ['塔纳'] ==> 塔纳
# 49 replaced: Perly ['佩尔利'] ==> 佩利
# 17 replaced: Urgeat ['厄吉特'] ==> 乌吉特
# 15 replaced: Pasca ['帕斯卡'] ==> 帕丝卡
# 45 replaced: Nonton ['侬顿'] ==> 诺顿
# 21 replaced: Ingroed ['茵格洛徳'] ==> 茵格洛伊
# 1 replaced: Cletlan ['克莱特兰'] ==> 柯莱特兰
# 1 replaced: Nudwin ['努德温'] ==> 路德温
# 53 replaced: Nedmar ['内德马'] ==> 耐德玛
# 38 replaced: Giacco ['吉亚科'] ==> 贾克
# 5 replaced: Nridek ['恩里德克'] ==> 尼瑞戴
# 35 replaced: Trygil ['切基尔'] ==> 提吉尔
# 29 replaced: Hendyna ['亨戴娜'] ==> 亨黛娜
# 13 replaced: Winfrith ['温弗里斯'] ==> 温弗里斯
# 8 replaced: Nestor Harond ['内斯特·哈罗德'] ==> 奈斯托·哈隆德
# 38 replaced: Rumbald ['鲁姆巴尔德'] ==> 朗博德
# 10 replaced: Beodmar ['贝奥德玛'] ==> 毕德玛
# 11 replaced: Dengler ['丹格勒', '登格勒'] ==> 邓格勒
# 52 replaced: Medreth ['梅德雷斯'] ==> 麦德雷斯
# 66 replaced: nyfre ['妮芙蕾'] ==> 奈芙薇
# 17 replaced: Korgrak ['寇格拉克'] ==> 寇格拉克
# 1 replaced: Celby ['塞尔比'] ==> 赛尔彼
# 1 replaced: Elfya ['艾菲亚'] ==> 埃尔法
# 1 replaced: Talyna ['塔里纳'] ==> 塔莱娜
# 3 replaced: Norgar ['诺加'] ==> 诺加
# 5 replaced: Raolf ['劳尔夫'] ==> 拉尔夫
# 2 replaced: Blissa ['布里萨'] ==> 比利萨
# 1 replaced: Oedemar ['欧德马'] ==> 欧德玛
# 16 replaced: Peregund ['佩瑞刚德'] ==> 裴丽甘
# 9 replaced: Hanwen ['汉温'] ==> 韩汶
# 14 replaced: Aldmar ['阿尔德玛尔'] ==> 阿尔玛
# 41 replaced: Dunstan ['邓斯坦'] ==> 邓斯坦
# 57 replaced: Penhelm ['潘赫姆'] ==> 潘亥姆
# 15 replaced: Wyla ['薇拉', '维拉', '怀拉'] ==> 怀娜
# 58 replaced: Clyver ['克莱韦尔'] ==> 克莱维
# 7 replaced: Vicent Agosti ['维森特·阿格斯蒂'] ==> 维森特·阿戈斯提
# 1 replaced: Sidly ['希德利'] ==> 西德尼
# 19 replaced: Fyrga ['菲尔佳'] ==> 弗莱嘉
# 8 replaced: Eldrid Wenfeld ['艾德里德·温菲尔德'] ==> 艾德黎德·温菲徳
# 8 replaced: Bragan ['布拉甘'] ==> 布拉甘
# 2 replaced: Cartugo ['卡图格'] ==> 卡图格
# 4 replaced: Liena ['列娜'] ==> 莲娜
# 30 replaced: Imatl ['伊马特尔'] ==> 以玛塔尔
# 25 replaced: Marceno ['马森诺'] ==> 玛希诺
# 14 replaced: Kolfecg ['科尔费格'] ==> 柯菲哲
# 20 replaced: Niah ['尼亚'] ==> 尼娅
# 4 replaced: Curnd ['库恩德'] ==> 库伦德
# 55 replaced: Serel ['赛瑞尔'] ==> 瑟蕊儿
# 60 replaced: Maea ['玛伊娅'] ==> 梅娅
# 4 replaced: Llines ['“双唇”莱恩斯'] ==> “双唇”莱丽丝
# 4 replaced: Orico ['奥利克'] ==> 奥睿柯
# 3 replaced: Gjefa ['吉耶法'] ==> 耶法
# 3 replaced: Iqali ['伊卡里'] ==> 伊佳丽
# 3 replaced: Lyrinia ['利瑞尼亚'] ==> 莱尼丽雅
# 2 replaced: Big Durmsey ['大邓姆西'] ==> 大戴姆曦
# 3 replaced: Aldwyn ['奥德维恩'] ==> 阿德汶
# 28 replaced: Danna ['丹娜'] ==> 丹娜
# 14 replaced: Antonino ['安东尼奥'] ==> 安东尼欧
# 56 replaced: Derrin ['德林'] ==> 戴林
# 13 replaced: Abrecan Doemenel ['爱波里肯', '雅布雷坎'] ==> 阿博瑞肯
# 15 replaced: Gedmar Doemenel ['盖德马尔'] ==> 盖德玛
# 10 replaced: Bricanta Doemenel ['布里坎塔'] ==> 布瑞坎达
# 284 replaced: Doemenel ['德梅尼尔'] ==> 多伊门内
# 6 replaced: Linete Reymont ['丽奈特·雷蒙特', '里内特·雷蒙特'] ==> 莉涅·雷蒙特
# 34 replaced: Ethelmoer ['伊塞默尔'] ==> 艾瑟莫尔
# 22 replaced: Caedman Azo ['凯德曼亚佐', '凯德曼·亚佐'] ==> 凯德曼·阿佐
# 4 replaced: Riply ['里普莱'] ==> 瑞普莱
# 44 replaced: Kurren ['库伦'] ==> 库仑
# 20 replaced: Nedyn ['内等', '内丁', '内戴恩'] ==> 奈丹
# 7 replaced: Fexa ['菲克莎', '菲克萨'] ==> 菲克萨
# 19 replaced: Bellasege ['贝拉赛格', '贝拉塞杰伊'] ==> 贝拉瑟吉
# 51 replaced: Moedred ['莫德雷德'] ==> 莫德雷德
# 8 replaced: Uscgrim ['尤斯格里姆', '乌什格里姆'] ==> 厄格利姆
# 74 replaced: Gram ['格拉姆'] ==> 格兰姆
# 3 replaced: Audmer ['奥德摩尔'] ==> 阿德梅
# 26 replaced: Nans ['楠丝'] ==> 南斯
# 8 replaced: Freyol ['弗雷约', '弗雷尤尔'] ==> 弗瑞尤
# 4 replaced: Emilo Valtas ['艾米洛·瓦尔塔斯'] ==> 爱弥洛·瓦塔司
# 1 replaced: Isel Maerith, Lady Valtas ['伊塞尔·马里斯', '瓦尔塔斯夫人'] ==> 瓦塔司夫人,伊莎·梅里斯
# 1 replaced: Valerio Valtas, Lord of House Valtas ['维勒里奥·瓦尔塔斯', '瓦尔塔斯家族领主'] ==> 瓦塔司家主,瓦勒里奥·瓦塔司
# 2 replaced: Saeda Valtas ['赛达·瓦尔塔斯'] ==> 席达·瓦塔司
# 23 replaced: Saeda ['赛达'] ==> 席达
# 31 replaced: Valtas ['瓦尔塔斯'] ==> 瓦塔司
# 36 replaced: Icantha ['伊坎莎'] ==> 凯珊
# 4 replaced: Aldhelm Graeg ['奥尔德尔姆·格雷格', '奥尔德海姆格莱格'] ==> 亚亥姆·葛瑞格
# 12 replaced: Leyra ['利拉'] ==> 蕾拉
# 4 replaced: Rowan ['罗恩', '罗万'] ==> 洛万
# 5 replaced: Narmer ['纳尔默'] ==> 纳尔默
# 13 replaced: Igrun ['伊格伦'] ==> 伊格朗
# 51 replaced: Lora ['劳拉'] ==> 萝拉
# 11 replaced: Byne ['拜恩'] ==> 拜恩
# 44 replaced: Wenan ['维南'] ==> 威南
# 2 replaced: Wyglan ['怀格兰'] ==> 怀格兰
# 2 replaced: Bandon Leer ['班登·里尔'] ==> 班登·尼尔
# 63 replaced: Osric ['奥斯里克'] ==> 奥斯尼克
# 9 replaced: Sonild ['索尼尔德'] ==> 索奈德
# 61 replaced: Kaenra ['吉恩拉'] ==> 柯伦娜
# 2 replaced: Dread-Shot Daedon ['恐惧射手-迪顿'] ==> “恐怖射手”戴登
# 3 replaced: Hurdy ['赫尔迪'] ==> 赫迪
# 5 replaced: Ilfa ['伊尔法'] ==> 纳法
# 2 replaced: Two-Tone Weaxel ['双调-维克赛尔', '双调人维克赛尔'] ==> “双音”韦克斯勒
# 42 replaced: Gordy ['格尔迪'] ==> 戈迪
# 36 replaced: Dalton ['达尔顿'] ==> 达尔顿
# 42 replaced: Lumdala ['伦达拉'] ==> 纳达拉
# 21 replaced: Kadal ['卡达', '卡达尔尔'] ==> 卡达尔
# 129 replaced: Purnisc ['普尔尼斯克'] ==> 柏尼士
# 6 replaced: Coren ['科朗'] ==> 科伦
# 51 replaced: Grimda ['格里姆达'] ==> 格尼姆达
# 7 replaced: Langden ['郎登'] ==> 朗登
# 2 replaced: Dirty Rigbert ['下流的里博特'] ==> 下流坯利博特
# 2 replaced: Deysy ['迪西'] ==> 迪希
# 4 replaced: Slecg ['斯莱吉'] ==> 斯莱戈
# 24 replaced: Nyrid ['尼里德'] ==> 奈尼德
# 12 replaced: Gareth ['加雷斯'] ==> 盖瑞斯
# 18 replaced: Bledha ['布雷达'] ==> 贝莱达
# 1 replaced: Vesgel ['维斯格尔'] ==> 维斯盖尔
# 29 replaced: Alwah ['阿尔瓦'] ==> 阿尔瓦
# 1 replaced: Rotuk ['罗图克'] ==> 罗图克
# 1 replaced: Ellitherion 'Haggard Shoes' ['“尖鞋子”艾利西里昂'] ==> ‘烂鞋’艾利瑟利昂
# 34 replaced: Cwineth ['克温尼斯'] ==> 席纹尼丝
# 1 replaced: Sileira Trilere ['席雷拉·特里雷尔'] ==> 希蕾拉·特利勒瑞
# 9 replaced: Tamra ['塔姆拉'] ==> 塔姆拉
# 4 replaced: Derwn ['德尔温'] ==> 德伦
# 2 replaced: Masdên ['马斯登'] ==> 马斯敦
# 3 replaced: Rhanet ['拉内特'] ==> 拉内特
# 48 replaced: Alarhî ['阿拉茜'] ==> 阿拉睿
# 4 replaced: Iŵen ['伊文'] ==> 依文
# 9 replaced: Iswld ['伊苏尔德'] ==> 斯沃德
# 5 replaced: Tamrwn ['塔姆里恩'] ==> 塔姆恩
# 88 replaced: Arthwn ['阿瑟恩'] ==> 阿瑟恩
# 15 replaced: Lliras ['利拉斯'] ==> 莱纳斯
# 71 replaced: Simoc ['西蒙克'] ==> 希默克
# 1 replaced: Keeper Garost ['守护者格洛斯特'] ==> 伽罗斯看守
# 7 replaced: Keeper Wrdha ['看守人沃德哈', '守护者沃德哈'] ==> 淮萨看守
# 2 replaced: Tallan ['塔兰'] ==> 塔岚
# 22 replaced: Rehstin ['伊莱斯丁'] ==> 睿斯汀
# 21 replaced: Casfath ['卡斯法斯'] ==> 喀芬斯
# 26 replaced: Onŵen ['昂文'] ==> 纽茵
# 7 replaced: Dorvhal ['多法尔'] ==> 多瓦尔
# 8 replaced: Einden ['艾恩登'] ==> 艾因登
# 11 replaced: Desthwn ['戴斯恩'] ==> 戴斯汶
# 13 replaced: Larha ['拉尔哈'] ==> 纳哈
# 49 replaced: Oernos ['欧尔诺斯'] ==> 欧诺斯
# 7 replaced: Anamenfath Bethwl ['灵魂公主-贝苏尔', '灵魂王子贝苏尔'] ==> 灵魂君主贝瑟尔
# 2 replaced: Ŵidhwn ['韦德恩'] ==> 薇德恒
# 60 replaced: Okrun ['奥克伦'] ==> 欧库仑
# 550 replaced: Ista ['伊斯塔'] ==> 伊斯塔
# 64 replaced: Lafda ['拉弗达'] ==> 拉弗达
# 25 replaced: Tealdor ['提尔多'] ==> 提尔铎
# 59 replaced: Reyfald ['雷法尔德'] ==> 瑞法德
# 17 replaced: Yduran ['叶杜兰', '耶都'] ==> 依德兰
# 65 replaced: Thyrsc ['塞斯克'] ==> 希尔斯
# 35 replaced: Feara ['菲亚拉'] ==> 费阿
# 6 replaced: Byrhtwen ['白屯'] ==> 拜特温
# 14 replaced: Andred ['安德'] ==> 安德鲁
# 5 replaced: Lynam ['莱纳姆'] ==> 丽娜姆
# 11 replaced: Francesca ['弗朗西斯卡'] ==> 弗朗西丝卡
# 24 replaced: Owynna ['欧亚娜'] ==> 奥雯娜
# 32 replaced: Ailef ['艾利弗'] ==> 艾利芙
# 33 replaced: Defala ['戴发拉'] ==> 狄珐拉
# 87 replaced: Haeferic ['海弗瑞克'] ==> 海弗利克
# 14 replaced: Teanleycg ['丁里克'] ==> 汀利哲
# 22 replaced: Uldric ['奥尔德里奇'] ==> 欧德利克
# 75 replaced: Renengild ['雷纳吉尔德', '雷南吉尔德'] ==> 睿娜吉德
# 26 replaced: Matron Beregan ['主管贝雷甘', '贝雷甘主管', '主管·贝雷甘', 'MatronBergegan', '狱卒贝若根'] ==> 霸主贝拉刚
# 50 replaced: Grynde ['格莱恩德'] ==> 盖恩德
# 2 replaced: Baetti ['拜蒂'] ==> 拜悌
# 3 replaced: Palloc ['帕洛克'] ==> 帕洛克
# 2 replaced: Naedle ['娜艾德'] ==> 奈德尔
# 7 replaced: Clerk ['职员'] ==> 克勒克
# 30 replaced: Suldrun ['苏尔德伦'] ==> 萨德朗
# 22 replaced: Tarfos ['塔夫斯', '塔福斯'] ==> 塔佛斯
# 46 replaced: Masca ['马斯卡'] ==> 玛斯卡
# 3 replaced: Gytha ['吉塔'] ==> 盖撒
# 29 replaced: Nesta ['内斯塔'] ==> 奈斯塔
# 5 replaced: Foreman Ismey ['工头伊斯梅', '工头埃斯梅'] ==> 工头艾斯梅
# 59 replaced: Harmke ['哈姆克'] ==> 哈穆柯
# 51 replaced: Haddi ['哈迪', '哈蒂', '海蒂'] ==> 哈笛
# 9 replaced: Elwyna ['埃温纳'] ==> 爱尔怀娜
# 39 replaced: Cevestin ['西维斯汀', '查维斯提', '塞维斯汀'] ==> 赛维斯汀
# 43 replaced: Eska ['埃斯卡', '阿斯卡'] ==> 艾斯卡
# 3 replaced: Brys ['布里斯', '比尔斯'] ==> 拜尔斯
# 2 replaced: Kosta ['科斯塔'] ==> 孔斯塔
# 40 replaced: Kern ['科恩', '克恩'] ==> 柯恩
# 9 replaced: Taragaer ['塔拉吉斯'] ==> 塔拉伽
# 23 replaced: Royse ['罗伊斯', '洛熙'] ==> 罗伊瑟
# 105 replaced: Asca ['阿斯卡'] ==> 阿丝卡
# 26 replaced: Benno ['本诺'] ==> 贝诺
# 14 replaced: Emery ['埃梅里'] ==> 艾梅莉
# 2 replaced: Beasca ['贝斯卡'] ==> 比斯卡
# 87 replaced: Mylla ['麦拉'] ==> 迈拉
# 16 replaced: Lödgar ['洛加尔'] ==> 洛珈
# 29 replaced: Wengra ['温格拉'] ==> 温戈娜
# 11 replaced: Culmar ['库尔玛'] ==> 卡尔玛
# 24 replaced: Marunn ['马伦'] ==> 马伦
# 18 replaced: Exandru ['艾克桑德鲁'] ==> 山德鲁
# 33 replaced: Zoltun ['佐尔坦'] ==> 祖尔顿
# 15 replaced: Gregur ['格瑞格'] ==> 格瑞戈
# 2 replaced: Felisa ['费丽萨'] ==> 菲利萨
# 6 replaced: Darzir ['达契尔', 'Darzir'] ==> 达泽尔
# 129 replaced: Galvino ['加维诺'] ==> 加尔维诺
# 13 replaced: Cyneheod ['卡夫', 'Cyneheod', '辛和德'] ==> 塞尼德
# 19 replaced: Sabel ['萨贝儿', '萨贝尔'] ==> 沙贝尔
# 19 replaced: Pelden ['帕尔登', '派尔顿'] ==> 裴登
# 46 replaced: Tanoss ['塔诺斯'] ==> 塔诺斯
# 20 replaced: Uariki ['尤丽吉', '瓦里基'] ==> 瓦利吉
# 23 replaced: Hamond ['汉蒙德'] ==> 哈蒙德
# 6 replaced: Korbal ['科巴尔', '科巴'] ==> 拓拔尔
# 2 replaced: Wymarc ['维马尔克'] ==> 怀马克
# 27 replaced: Sameth ['萨梅思', '赛穆斯'] ==> 萨梅斯
# 37 replaced: Gamel ['甘梅尔', '哈默尔'] ==> 盖梅尔
# 13 replaced: Badrwn ['巴德温'] ==> 巴德温
# 11 replaced: Fulvano ['弗尔瓦诺'] ==> 伏瓦诺
# 18 replaced: Fortanero ['弗塔内洛'] ==> 弗塔纳罗
# 13 replaced: Mestre Verzano ['梅斯特·维扎诺', '维萨诺先生'] ==> 梅斯特·瓦扎罗
# 7 replaced: Merec ['梅里克'] ==> 梅瑞克
# 4 replaced: Ludrana ['露德拉娜', '卢德拉纳'] ==> 伦达娜
# 1 replaced: Foelmar ['弗欧马尔'] ==> 弗尔玛
# 1 replaced: Egdrang ['埃德朗'] ==> 艾哲朗
# 10 replaced: Tily ['蒂丽'] ==> 缇莉
# 3 replaced: Padebald ['帕德巴尔德'] ==> 佩德巴尔德
# 10 replaced: Aranroed ['阿兰略德', '雅兰洛德'] ==> 阿岚罗伊
# 35 replaced: Vianna ['薇安娜'] ==> 薇安娜
# 3 replaced: Sevis ['塞维斯'] ==> 赛维斯
# 3 replaced: Iben ['艾本'] ==> 伊本
# 1 replaced: Beacwof ['贝赫沃夫'] ==> 贝卡伍夫
# 1 replaced: Eagar ['伊加'] ==> 艾哲
# 1 replaced: Venka ['文卡'] ==> 文卡
# 1 replaced: Frya Manhem ['弗莱亚·曼赫姆'] ==> 菲娅·曼赫姆
# 1 replaced: Ableheart Skerrion ['亚伯哈特·斯凯里昂'] ==> 阿博哈特·斯科瑞昂
# 8 replaced: Skerrion ['斯凯里昂'] ==> 斯科瑞昂
# 24 replaced: Baelorin ['贝罗林'] ==> 橘欧林
# 13 replaced: Arkemyr ['阿克米尔'] ==> 亚柯弥
# 31 replaced: Minoletta ['米诺莱塔'] ==> 靡奥塔
# 126 replaced: Concelhaut ['康瑟豪特'] ==> 康赛豪
# 13 replaced: Kalakoth ['卡拉科斯'] ==> 卡拉寇
# 6 replaced: Citzal ['希特扎尔'] ==> 席扎尔
# 72 replaced: Llengrath ['勒伦格拉斯'] ==> 郎歌世
# 2 replaced: Ryngrim ['莱格里姆'] ==> 兰格瑞
# 20 replaced: Ninagauth ['尼纳加乌斯'] ==> 耐高司
# 49 replaced: Osrya ['欧丝丽亚'] ==> 奥瑟亚
# 23 replaced: Falanroed ['法兰略德'] ==> 法兰若
# 65 replaced: Rinatto ['里纳托'] ==> 睿纳托
# 2 replaced: Surica ['苏里卡'] ==> 苏芮卡
# 2 replaced: Elvara ['伊尔薇拉', '艾尔瓦拉'] ==> 艾瓦拉
# 2 replaced: Harkeen ['哈吉恩', '哈奇恩'] ==> 哈金
# 3 replaced: Azrael ['亚兹拉尔'] ==> 殆天使
# 3 replaced: Telda ['黛尔达'] ==> 泰尔达
# 13 replaced: Selona ['赛罗纳', 'Selona'] ==> 瑟罗兰
# 33 replaced: Fyrgen ['费尔根'] ==> 费迩艮
# 8 replaced: Songsmith Roska ['战歌咏者罗丝卡'] ==> “谱曲家”洛丝卡
# 15 replaced: Daroth Grimault ['达罗斯·格里玛特'] ==> 达罗斯·格利摩特
# 12 replaced: The Dweller ['常居客'] ==> “原住民”
# 9 replaced: Devŵen ['戴弗温'] ==> 戴汶
# 10 replaced: Nalrend the Wise ['智者纳尔伦德'] ==> “聪明的”纳伦德
# 14 replaced: Sly Cyrdel ['斯莱·克莱戴尔'] ==> “狡猾的”赛德尔
# 14 replaced: Galen Dalgard ['盖伦·达加德'] ==> 贾伦·达嘉德
# 12 replaced: Thorfen ['索尔法恩'] ==> 托尔芬
# 12 replaced: Foemyna ['弗米纳'] ==> 费尔米娜
# 10 replaced: Captain Muārumi ['穆亚鲁米船长', '船长穆亚鲁米'] ==> 玛努米船长
# 13 replaced: Warchief Iklak ['伊克拉克酋长', '酋长伊克拉克'] ==> 艾克拉克酋长
# 12 replaced: Ysly ['雅斯莉'] ==> 伊思莱
# 11 replaced: Sserkal ['赛尔凯尔'] ==> 丝丝喀尔
# 12 replaced: Glasdial ['格拉斯戴尔'] ==> 伽斯迪尔
# 13 replaced: Laenric ['莱恩瑞克'] ==> 莲瑞克
# 15 replaced: Firedorn ['火多恩'] ==> 烈焰多恩
# 15 replaced: Meztla ['美斯特拉'] ==> 梅茨拉
# 8 replaced: The Gleaming Society ['闪光组织'] ==> 闪烁社
# 22 replaced: Ulmar ['尤马尔'] ==> 乌尔玛
# 14 replaced: Roedwith ['Roedwith', '罗迪维斯', '罗德维施', '罗伊维斯'] ==> 罗德维茨
# 19 replaced: Brynlod ['Brynlod', '布兰洛'] ==> 拜罗德
# 64 replaced: Lafda ['拉芙达'] ==> 拉弗达
# 16 replaced: Aefre ['艾弗雷'] ==> 艾弗莉
# 49 replaced: Eorn ['艾奥恩'] ==> 爱欧恩
# 18 replaced: Gramrfel ['格兰菲尔'] ==> 格兰菲尔
# 10 replaced: Kestorik ['凯斯托里克'] ==> 科丝卓克
# 5 replaced: Naelde ['奈尔德'] ==> 娜尔德
# 2 replaced: Esmer ['Esmer'] ==> 艾斯玛
# 26 replaced: Forwyn ['弗尔温'] ==> 佛维恩元帅
# 5 replaced: Geyda ['盖伊达', '盖达'] ==> 吉妲
# 10 replaced: Nyry ['尼莉', '尼瑞'] ==> 奈莉
# 15 replaced: Brynwigar ['布莱恩维格'] ==> 毕延尼加
# 3 replaced: Berolt ['希尔什', '贝洛特'] ==> 贝洛特
# 4 replaced: Azzuro ['艾祖洛'] ==> 阿祖罗
# 8 replaced: Solmar ['索马尔', '索尔玛'] ==> 梭尔玛
# 7 replaced: Gafol ['加弗尔'] ==> 贾福尔
# 1 replaced: Odeyna Fyrgest ['奥德伊纳·菲尔杰斯特'] ==> 奥黛娜·费盖斯特
# 5 replaced: Odeyna ['奥德纳'] ==> 奥黛娜
# 9 replaced: Sidroc ['希德洛克', '西德罗克'] ==> 席道克
# ===patch end
# ===strat fix
# ===patch end
# ===strat replace
# 312 replaced: Engwithan ['因格维斯', '因格维坦'] ==> 英格维仙
# 326 replaced: Engwith ['因格维斯', '因格维坦'] ==> 英格维仙
# 11 replaced: Iroccian calendar ['伊洛希奥历法', '伊洛希奥日历', '伊洛希奥历'] ==> 依洛齐奥历
# 210 replaced: Aedyran ['鹿丛人'] ==> 聚鹿人
# 356 replaced: Aedyr ['鹿丛'] ==> 聚鹿
# 4 replaced: Senn Beläfa ['塞恩·贝拉法', '塞恩贝拉法', '赛恩贝拉法'] ==> 宠月
# 35 replaced: Ionni Brathr ['艾沃尼布拉瑟尔', 'IonniBrathr'] ==> 艾尼·布拉瑟
# 1 replaced: Cawldha Dev ['卡沃达·德弗'] ==> 黑月
# 397 replaced: Adra ['绿萤'] ==> 魂珀
# 1 replaced: Lover's Tide ['爱之潮'] ==> 宠潮
# 34 replaced: Bîaŵac ['噬魂风暴'] ==> 别瓦寇
# 1 replaced: spirit winds ['灵能风暴'] ==> 魂风
# 140 replaced: Hollowborn ['无魂儿'] ==> 空婴
# 26 replaced: Salvation ['救赎'] ==> 救恩
# 27 replaced: Purges ['屠杀', '净化', '大清洗', '清洗'] ==> 大肃清
# 459 replaced: Watcher ['通魂者'] ==> 观魂者
# 27 replaced: Broken Stone War ['碎石之战'] ==> 碎石战争
# 36 replaced: War of Black Trees ['黑树之战'] ==> 焦木之战
# 1 replaced: fercönyngs ['帝王'] ==> 至尊王
# 16 replaced: mecwyn ['帝后', '女王', '辉耀女王'] ==> 辉耀后
# ===patch end
# ===strat replace
# 202 replaced: Abydon ['艾比顿', 'Abydon'] ==> 亚拜登
# 178 replaced: Berath ['贝拉斯', 'Berath'] ==> 贝拉斯
# 13 replaced: The Twinned God ['双子神', '双子之神'] ==> 双子神
# 3 replaced: Cirono ['希洛诺'] ==> 希若洛
# 5 replaced: Bewnen i Ankew and Ankew i Bewnen ['生命中的死亡和死亡中的生命', '生命与死亡'] ==> 生死相依
# 18 replaced: The Usher ['指引者'] ==> 引魂人
# 178 replaced: Eothas ['伊欧萨斯', '伊欧撒斯', 'Eothas'] ==> 俄撒斯
# 3 replaced: The Shattered God ['破碎之神0'] ==> 炸碎的神
# 41 replaced: Gaun ['戈恩'] ==> 冈恩
# 219 replaced: Galawain ['加拉维恩', 'Galawain'] ==> 伽拉温
# 15 replaced: The Seeker God ['探求之神'] ==> 探寻之神
# 8 replaced: The Clever Hound ['灵犬'] ==> 机巧猎犬
# 7 replaced: Lord of the Hunt ['狩猎之神'] ==> 狩猎之主
# 107 replaced: Hylea ['海莉亚', 'Hylea'] ==> 海丽娅
# 12 replaced: Sky-Mother ['天空之母'] ==> 天空之母
# 6 replaced: Queen of Birds ['百鸟女皇'] ==> 飞鸟女神
# 232 replaced: Magran ['玛格岚', '马格岚'] ==> 玛珈岚
# 367 replaced: Ondra ['Ondra'] ==> 昂德拉
# 12 replaced: The Lady of Lament ['悲痛女神'] ==> 哀歌女士
# 4 replaced: Salty Wench ['饱受风吹雨打的少妇', '粗俗荡妇'] ==> 咸海少女
# 114 replaced: Giftbearer ['礼物持有人', '信物收集者', '持宝者', '天赋异禀者', 'Giftbearer'] ==> 巡礼者
# 83 replaced: Rymrgand ['里姆甘德', 'Rymrgand'] ==> 睿姆冈
# 14 replaced: The Beast of Winter ['寒冬之兽'] ==> 寒冬巨兽
# 87 replaced: Skaen ['斯卡恩', '歌贝纳', 'Skaen'] ==> 司坎
# 2 replaced: The Schemer ['阴谋家'] ==> 阴谋者
# 15 replaced: The Effigy ['雕像'] ==> 化神
# 164 replaced: Wael ['瓦尔', '威尔', 'Wael'] ==> 沃艾珥
# 9 replaced: The Obscured ['隐匿者', '隐蔽的事物', '隐匿之神'] ==> 胧纱者
# 5 replaced: The Eyeless Face ['没有眼睛的脸', '无眼之面', '无眼面孔'] ==> 无目之面
# 5 replaced: The Hundred Visions ['百年愿景'] ==> 万千幻景
# 3 replaced: He Who Sees and Is Not Seen ['洞察万物而无人可见者', '看而不被看的神', '似隐而现之神'] ==> 视之非视之人
# 177 replaced: Woedica ['沃迪卡', 'Woedica'] ==> 娥狄卡
# 7 replaced: Queen that Was ['曾经和现在的女王', '曾经的女王', '曾经女王', '曾经女皇'] ==> 往昔女王
# 6 replaced: Oathbinder ['誓缚者'] ==> 缚誓者
# 5 replaced: Burned Queen ['燃烧女王'] ==> 火焚之后
# 8 replaced: Exiled Queen ['流亡女皇'] ==> 流亡女皇
# 8 replaced: Darcozzi Paladini ['达科兹圣武士'] ==> 达寇茨圣武团
# 5 replaced: Goldpact Knights ['金钱会骑士团'] ==> 金盟骑士团
# 37 replaced: Bleak Walkers ['阴冷行者'] ==> 荒芜行者
# 1 replaced: Fellow of St. Waidwen ['圣维德文的伙计'] ==> 殉道者圣维德温之门徒
# 2 replaced: The Shieldbearers of St. Elcga ['圣依尔佳之持盾者', '圣伊尔佳之持盾者'] ==> 圣伊尔佳盾卫
# 15 replaced: Kind Wayfarers ['善良护旅团'] ==> 友善旅人
# 167 replaced: The Dozen ['卫邦十二人团'] ==> 十二人众
# 220 replaced: Dozens ['卫邦十二人团'] ==> 十二人众
# 61 replaced: Dunryd Row ['顿瑞德街道办', '顿瑞德街道'] ==> 遁亚路
# 47 replaced: The Knights of the Crucible ['炼狱骑士团', '炼狱骑士的代表团', '炼狱骑士', '炼狱'] ==> 坩锅骑士团
# 54 replaced: Knights of the Crucible ['炼狱骑士'] ==> 坩锅骑士
# 19 replaced: High Justice ['大法官'] ==> 高义爵
# 29 replaced: Novitiate ['修士'] ==> 见习骑士
# 27 replaced: Justiciar ['审判者', '裁判法官'] ==> 正法士
# 121 replaced: Commander ['指挥官', '高级骑士'] ==> 正法长
# 74 replaced: Marshal ['元帅', '马歇尔·', '马歇尔'] ==> 正法官
# 1 replaced: Lord Justiciar ['审判之王'] ==> 大正法长
# 2 replaced: Lord Marshal ['大元帅'] ==> 大正法官
# 3 replaced: Templus ['圣殿武士'] ==> 铸士
# 6 replaced: Forge Master ['锻造大师'] ==> 铸师
# 2 replaced: Crucilar ['圣灵骑士'] ==> 铸匠
# 1 replaced: Grand Templus ['圣殿武士长'] ==> 大铸士
# 1 replaced: Lord Crucilar ['圣灵骑士长'] ==> 大铸匠
# 147 replaced: Fangs ['獠牙'] ==> 尖牙
# 39 replaced: Ethik Nôl ['自然哲理'] ==> 无伦会
# 4 replaced: Ethik Nol ['自然哲理'] ==> 无伦会
# 86 replaced: House Doemenel ['德梅尼尔家族'] ==> 多伊门内家族
# 12 replaced: Ovates of the Golden Grove ['金丛愿灵'] ==> 金林众贤
# 27 replaced: Ovates ['愿灵'] ==> 众贤
# 2 replaced: The Steel Garrote ['钢绞团'] ==> 铁绞喉
# 6 replaced: Hand Occult ['神秘之手'] ==> 掌秘人
# 202 replaced: Leaden Key ['暗灰之钥'] ==> 灰钥社
# 2 replaced: Night Market ['夜市'] ==> 暗夜集会
# 82 replaced: Iron Flail ['铁链枷', '链枷骑兵', '铁枷骑兵'] ==> 铁枷团
# 35 replaced: Birthing Bell ['产铃育儿院'] ==> 新生之铃
# ===patch end
# ===patched
